# %%
import numpy as np
import pandas as pd

# %%
# creating a dictionary for dataframe
emp={
    "EMP_ID":[101,102,103,104,105],
    "EMP_NAME":["Mukul","Ritika","Prateek","Atul","Priyanshu"],
    "EMP_SAL":[35300,25500,np.nan,56000,np.nan],
    "EMP_COMPANY":["Google","Microsoft","OpenAI","Google",np.nan],
    "EMP_COUNTRY":["INDIA","BHARAT","USA","DUBAI","SPAIN"]
}

# %%
df= pd.DataFrame(emp)

# %%
df
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  35300.0      Google       INDIA
# 1     102     Ritika  25500.0   Microsoft      BHARAT
# 2     103    Prateek      NaN      OpenAI         USA
# 3     104       Atul  56000.0      Google       DUBAI
# 4     105  Priyanshu      NaN         NaN       SPAIN

# %%
df.isnull()
# Out:
#    EMP_ID  EMP_NAME  EMP_SAL  EMP_COMPANY  EMP_COUNTRY
# 0   False     False    False        False        False
# 1   False     False    False        False        False
# 2   False     False     True        False        False
# 3   False     False    False        False        False
# 4   False     False     True         True        False

# %%
df.isnull().sum()
# Out:
# EMP_ID         0
# EMP_NAME       0
# EMP_SAL        2
# EMP_COMPANY    1
# EMP_COUNTRY    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(3)

# %%
df.shape
# Out:
# (5, 5)

# %%
print("Rows: ",df.shape[0])
# Out:
# Rows:  5

# %%
print("Column: ",df.shape[1])
# Out:
# Column:  5

# %%
print("Total Cell: ",df.shape[0]*df.shape[1])
# Out:
# Total Cell:  25

# %%
print("Missing Values: ",df.isnull().sum().sum())
# Out:
# Missing Values:  3

# %%
print("Missing Value %age: ",df.isnull().sum().sum()/(df.shape[0]*df.shape[1])*100)
# Out:
# Missing Value %age:  12.0

# %%
df
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  35300.0      Google       INDIA
# 1     102     Ritika  25500.0   Microsoft      BHARAT
# 2     103    Prateek      NaN      OpenAI         USA
# 3     104       Atul  56000.0      Google       DUBAI
# 4     105  Priyanshu      NaN         NaN       SPAIN

# %%
df.dropna()
# Out:
#    EMP_ID EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101    Mukul  35300.0      Google       INDIA
# 1     102   Ritika  25500.0   Microsoft      BHARAT
# 3     104     Atul  56000.0      Google       DUBAI

# %%
df
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  35300.0      Google       INDIA
# 1     102     Ritika  25500.0   Microsoft      BHARAT
# 2     103    Prateek      NaN      OpenAI         USA
# 3     104       Atul  56000.0      Google       DUBAI
# 4     105  Priyanshu      NaN         NaN       SPAIN

# %%
# we can not fill all values at once like this

df.fillna(value="Missing")
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  35300.0      Google       INDIA
# 1     102     Ritika  25500.0   Microsoft      BHARAT
# 2     103    Prateek  Missing      OpenAI         USA
# 3     104       Atul  56000.0      Google       DUBAI
# 4     105  Priyanshu  Missing     Missing       SPAIN

# %%
df
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  35300.0      Google       INDIA
# 1     102     Ritika  25500.0   Microsoft      BHARAT
# 2     103    Prateek      NaN      OpenAI         USA
# 3     104       Atul  56000.0      Google       DUBAI
# 4     105  Priyanshu      NaN         NaN       SPAIN

# %%
df["EMP_SAL"]
# Out:
# 0    35300.0
# 1    25500.0
# 2        NaN
# 3    56000.0
# 4        NaN
# Name: EMP_SAL, dtype: float64

# %%
df["EMP_SAL"] = df["EMP_SAL"].fillna(value=20000)

# %%
df
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  35300.0      Google       INDIA
# 1     102     Ritika  25500.0   Microsoft      BHARAT
# 2     103    Prateek  20000.0      OpenAI         USA
# 3     104       Atul  56000.0      Google       DUBAI
# 4     105  Priyanshu  20000.0         NaN       SPAIN

# %%
df["EMP_COMPANY"].mode()[0]
# Out:
# 'Google'

# %%
df["EMP_COMPANY"] = df["EMP_COMPANY"].fillna(value=df["EMP_COMPANY"].mode()[0])

# %%
df
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  37300.0      Google         IND
# 1     102     Ritika  27500.0   Microsoft         BHA
# 2     103    Prateek  22000.0      OpenAI         USA
# 3     104       Atul  58000.0      Google         DUB
# 4     105  Priyanshu  22000.0     Missing         SPA

# %%
df["EMP_COMPANY"]
# Out:
# 0       Google
# 1    Microsoft
# 2       OpenAI
# 3       Google
# 4      Missing
# Name: EMP_COMPANY, dtype: object

# %%
df["EMP_COMPANY"]=df["EMP_COMPANY"].fillna(value="Google")

# %%
df
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  39300.0      Google         IND
# 1     102     Ritika  29500.0   Microsoft         BHA
# 2     103    Prateek  24000.0      OpenAI         USA
# 3     104       Atul  60000.0      Google         DUB
# 4     105  Priyanshu  24000.0     Missing         SPA

# %%
sum(df["EMP_SAL"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-a577ac8c9e0c> in <cell line: 0>()
# ----> 1 sum(df["EMP_SAL"])
#
# TypeError: 'int' object is not callable

# %%
df
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  39300.0      Google         IND
# 1     102     Ritika  29500.0   Microsoft         BHA
# 2     103    Prateek  24000.0      OpenAI         USA
# 3     104       Atul  60000.0      Google         DUB
# 4     105  Priyanshu  24000.0     Missing         SPA

# %%
df["EMP_COMPANY"].mode()[0]
# Out:
# 'Google'

# %%
df["EMP_COMPANY"] = df["EMP_COMPANY"].fillna(value=df["EMP_COMPANY"].mode()[0])

# %%
df
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  39300.0      Google         IND
# 1     102     Ritika  29500.0   Microsoft         BHA
# 2     103    Prateek  24000.0      OpenAI         USA
# 3     104       Atul  60000.0      Google         DUB
# 4     105  Priyanshu  24000.0     Missing         SPA

# %%
df.fillna(method="ffill")
# Out:
# <ipython-input-150-5a0d178a1f3e>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  39300.0      Google         IND
# 1     102     Ritika  29500.0   Microsoft         BHA
# 2     103    Prateek  24000.0      OpenAI         USA
# 3     104       Atul  60000.0      Google         DUB
# 4     105  Priyanshu  24000.0     Missing         SPA

# %%
df
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  39300.0      Google         IND
# 1     102     Ritika  29500.0   Microsoft         BHA
# 2     103    Prateek  24000.0      OpenAI         USA
# 3     104       Atul  60000.0      Google         DUB
# 4     105  Priyanshu  24000.0     Missing         SPA

# %%
df.ffill()
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  39300.0      Google         IND
# 1     102     Ritika  29500.0   Microsoft         BHA
# 2     103    Prateek  24000.0      OpenAI         USA
# 3     104       Atul  60000.0      Google         DUB
# 4     105  Priyanshu  24000.0     Missing         SPA

# %%
df
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  39300.0      Google         IND
# 1     102     Ritika  29500.0   Microsoft         BHA
# 2     103    Prateek  24000.0      OpenAI         USA
# 3     104       Atul  60000.0      Google         DUB
# 4     105  Priyanshu  24000.0     Missing         SPA

# %%
df= df.ffill()

# %%
df
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  39300.0      Google         IND
# 1     102     Ritika  29500.0   Microsoft         BHA
# 2     103    Prateek  24000.0      OpenAI         USA
# 3     104       Atul  60000.0      Google         DUB
# 4     105  Priyanshu  24000.0     Missing         SPA

# %%
def Country(value):
  return value[:3]

# %%
df["EMP_COUNTRY"] = df["EMP_COUNTRY"].map(Country)

# %%
df
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  39300.0      Google         IND
# 1     102     Ritika  29500.0   Microsoft         BHA
# 2     103    Prateek  24000.0      OpenAI         USA
# 3     104       Atul  60000.0      Google         DUB
# 4     105  Priyanshu  24000.0     Missing         SPA

# %%
def updatesalary(sal):
  return sal+2000

# %%
df
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  39300.0      Google         IND
# 1     102     Ritika  29500.0   Microsoft         BHA
# 2     103    Prateek  24000.0      OpenAI         USA
# 3     104       Atul  60000.0      Google         DUB
# 4     105  Priyanshu  24000.0     Missing         SPA

# %%
df["EMP_SAL"] = df["EMP_SAL"].map(updatesalary)

# %%
df
# Out:
#    EMP_ID   EMP_NAME  EMP_SAL EMP_COMPANY EMP_COUNTRY
# 0     101      Mukul  41300.0      Google         IND
# 1     102     Ritika  31500.0   Microsoft         BHA
# 2     103    Prateek  26000.0      OpenAI         USA
# 3     104       Atul  62000.0      Google         DUB
# 4     105  Priyanshu  26000.0     Missing         SPA
